# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.343978
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *When W is nearly a zero matrix loss = -log(1/number of classes). here number of classes=10 hence loss = -log(0.1)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 2.171142 analytic: 2.171141, relative error: 1.627266e-08
# numerical: 0.400820 analytic: 0.400820, relative error: 5.040518e-08
# numerical: 1.380600 analytic: 1.380600, relative error: 4.551984e-08
# numerical: -2.040608 analytic: -2.040608, relative error: 4.882013e-09
# numerical: 0.577150 analytic: 0.577150, relative error: 7.138072e-08
# numerical: -0.277016 analytic: -0.277016, relative error: 2.390908e-07
# numerical: -0.889613 analytic: -0.889613, relative error: 2.807468e-08
# numerical: -5.039652 analytic: -5.039652, relative error: 1.032463e-08
# numerical: -0.020561 analytic: -0.020561, relative error: 8.030967e-07
# numerical: -1.146366 analytic: -1.146366, relative error: 8.312084e-09
# numerical: -2.837108 analytic: -2.837108, relative error: 1.218638e-08
# numerical: 2.195394 analytic: 2.195394, relative error: 2.770568e-08
# numerical: 0.850851 analytic: 0.850851, relative error: 2.998686e-08
# numerical: 0.631710 analytic: 0.631710, relative error: 7.744426e-08
# numerical: -2.336302 analytic: -2.336302, relative error: 6.923597e-09
# numerical: 1.446800 analytic: 1.446800, relative error: 1.211929e-08
# numerical: 0.427467 analytic: 0.427467, relative error: 4.715276e-08
# numerical: 1.635089 analytic: 1.635089, relative error: 1.690012e-08
# numerical: 1.647170 analytic: 1.647169, relative error: 5.062822e-08
# numerical: -0.107483 analytic: -0.107483, relative error: 2.625195e-10

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.343978e+00 computed in 0.132757s
# vectorized loss: 2.343978e+00 computed in 0.007698s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.linspace(8e-8, 2e-7,10)
regularization_strengths = np.linspace(1e4, 5e4,3)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
  for reg in regularization_strengths:
    clf=Softmax()
    loss_hist = clf.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=1500, verbose=True)
    y_train_pred = clf.predict(X_train)
    y_val_pred = clf.predict(X_val)
    train_acc=np.mean(y_train == y_train_pred)
    val_acc=np.mean(y_val == y_val_pred)
    results[(lr,reg)]=train_acc,val_acc
    if(val_acc>best_val):
        best_softmax=clf
        best_val=val_acc
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 310.617131
# iteration 100 / 1500: loss 224.595166
# iteration 200 / 1500: loss 163.056724
# iteration 300 / 1500: loss 118.569695
# iteration 400 / 1500: loss 86.441031
# iteration 500 / 1500: loss 63.270467
# iteration 600 / 1500: loss 46.384703
# iteration 700 / 1500: loss 34.207405
# iteration 800 / 1500: loss 25.355558
# iteration 900 / 1500: loss 18.886004
# iteration 1000 / 1500: loss 14.143174
# iteration 1100 / 1500: loss 10.910826
# iteration 1200 / 1500: loss 8.515440
# iteration 1300 / 1500: loss 6.623831
# iteration 1400 / 1500: loss 5.417502
# iteration 0 / 1500: loss 935.921905
# iteration 100 / 1500: loss 357.629589
# iteration 200 / 1500: loss 137.716507
# iteration 300 / 1500: loss 53.817592
# iteration 400 / 1500: loss 21.784637
# iteration 500 / 1500: loss 9.591403
# iteration 600 / 1500: loss 4.971029
# iteration 700 / 1500: loss 3.182322
# iteration 800 / 1500: loss 2.504187
# iteration 900 / 1500: loss 2.281046
# iteration 1000 / 1500: loss 2.192228
# iteration 1100 / 1500: loss 2.126766
# iteration 1200 / 1500: loss 2.028538
# iteration 1300 / 1500: loss 2.137832
# iteration 1400 / 1500: loss 2.082869
# iteration 0 / 1500: loss 1554.697742
# iteration 100 / 1500: loss 312.594295
# iteration 200 / 1500: loss 64.272036
# iteration 300 / 1500: loss 14.577173
# iteration 400 / 1500: loss 4.646553
# iteration 500 / 1500: loss 2.663291
# iteration 600 / 1500: loss 2.215335
# iteration 700 / 1500: loss 2.146672
# iteration 800 / 1500: loss 2.141930
# iteration 900 / 1500: loss 2.189370
# iteration 1000 / 1500: loss 2.141948
# iteration 1100 / 1500: loss 2.212168
# iteration 1200 / 1500: loss 2.143262
# iteration 1300 / 1500: loss 2.117046
# iteration 1400 / 1500: loss 2.106850
# iteration 0 / 1500: loss 311.372715
# iteration 100 / 1500: loss 213.557320
# iteration 200 / 1500: loss 147.369584
# iteration 300 / 1500: loss 101.856366
# iteration 400 / 1500: loss 70.520567
# iteration 500 / 1500: loss 48.943753
# iteration 600 / 1500: loss 34.304814
# iteration 700 / 1500: loss 24.244155
# iteration 800 / 1500: loss 17.185694
# iteration 900 / 1500: loss 12.518254
# iteration 1000 / 1500: loss 9.207089
# iteration 1100 / 1500: loss 6.942207
# iteration 1200 / 1500: loss 5.377445
# iteration 1300 / 1500: loss 4.305663
# iteration 1400 / 1500: loss 3.557628
# iteration 0 / 1500: loss 930.532266
# iteration 100 / 1500: loss 303.215150
# iteration 200 / 1500: loss 99.766567
# iteration 300 / 1500: loss 33.772097
# iteration 400 / 1500: loss 12.451423
# iteration 500 / 1500: loss 5.419028
# iteration 600 / 1500: loss 3.214060
# iteration 700 / 1500: loss 2.467572
# iteration 800 / 1500: loss 2.199809
# iteration 900 / 1500: loss 2.157359
# iteration 1000 / 1500: loss 2.083930
# iteration 1100 / 1500: loss 2.119768
# iteration 1200 / 1500: loss 2.109730
# iteration 1300 / 1500: loss 2.141394
# iteration 1400 / 1500: loss 2.104656
# iteration 0 / 1500: loss 1548.618466
# iteration 100 / 1500: loss 238.103447
# iteration 200 / 1500: loss 38.181273
# iteration 300 / 1500: loss 7.669166
# iteration 400 / 1500: loss 2.977432
# iteration 500 / 1500: loss 2.277126
# iteration 600 / 1500: loss 2.151349
# iteration 700 / 1500: loss 2.146350
# iteration 800 / 1500: loss 2.115745
# iteration 900 / 1500: loss 2.128591
# iteration 1000 / 1500: loss 2.169853
# iteration 1100 / 1500: loss 2.140476
# iteration 1200 / 1500: loss 2.142624
# iteration 1300 / 1500: loss 2.178460
# iteration 1400 / 1500: loss 2.145708
# iteration 0 / 1500: loss 312.367522
# iteration 100 / 1500: loss 202.550051
# iteration 200 / 1500: loss 132.583062
# iteration 300 / 1500: loss 86.886728
# iteration 400 / 1500: loss 57.146204
# iteration 500 / 1500: loss 38.028880
# iteration 600 / 1500: loss 25.418424
# iteration 700 / 1500: loss 17.217708
# iteration 800 / 1500: loss 11.927329
# iteration 900 / 1500: loss 8.453804
# iteration 1000 / 1500: loss 6.279640
# iteration 1100 / 1500: loss 4.711325
# iteration 1200 / 1500: loss 3.786666
# iteration 1300 / 1500: loss 3.192932
# iteration 1400 / 1500: loss 2.710198
# iteration 0 / 1500: loss 922.166309
# iteration 100 / 1500: loss 255.946097
# iteration 200 / 1500: loss 72.105442
# iteration 300 / 1500: loss 21.464474
# iteration 400 / 1500: loss 7.388247
# iteration 500 / 1500: loss 3.568238
# iteration 600 / 1500: loss 2.519054
# iteration 700 / 1500: loss 2.215859
# iteration 800 / 1500: loss 2.151468
# iteration 900 / 1500: loss 2.147367
# iteration 1000 / 1500: loss 2.134104
# iteration 1100 / 1500: loss 2.105823
# iteration 1200 / 1500: loss 2.092848
# iteration 1300 / 1500: loss 2.103473
# iteration 1400 / 1500: loss 2.106784
# iteration 0 / 1500: loss 1543.071596
# iteration 100 / 1500: loss 181.939454
# iteration 200 / 1500: loss 23.085000
# iteration 300 / 1500: loss 4.569042
# iteration 400 / 1500: loss 2.435229
# iteration 500 / 1500: loss 2.192847
# iteration 600 / 1500: loss 2.138415
# iteration 700 / 1500: loss 2.083169
# iteration 800 / 1500: loss 2.122180
# iteration 900 / 1500: loss 2.150655
# iteration 1000 / 1500: loss 2.163679
# iteration 1100 / 1500: loss 2.132682
# iteration 1200 / 1500: loss 2.137430
# iteration 1300 / 1500: loss 2.150367
# iteration 1400 / 1500: loss 2.153142
# iteration 0 / 1500: loss 313.704944
# iteration 100 / 1500: loss 193.116923
# iteration 200 / 1500: loss 119.738763
# iteration 300 / 1500: loss 74.611348
# iteration 400 / 1500: loss 46.708053
# iteration 500 / 1500: loss 29.562661
# iteration 600 / 1500: loss 19.012238
# iteration 700 / 1500: loss 12.513927
# iteration 800 / 1500: loss 8.483225
# iteration 900 / 1500: loss 6.042146
# iteration 1000 / 1500: loss 4.416312
# iteration 1100 / 1500: loss 3.478122
# iteration 1200 / 1500: loss 2.907312
# iteration 1300 / 1500: loss 2.538820
# iteration 1400 / 1500: loss 2.304153
# iteration 0 / 1500: loss 934.596915
# iteration 100 / 1500: loss 220.626502
# iteration 200 / 1500: loss 53.401986
# iteration 300 / 1500: loss 14.108573
# iteration 400 / 1500: loss 4.937080
# iteration 500 / 1500: loss 2.731236
# iteration 600 / 1500: loss 2.267032
# iteration 700 / 1500: loss 2.125392
# iteration 800 / 1500: loss 2.105019
# iteration 900 / 1500: loss 2.008848
# iteration 1000 / 1500: loss 2.153674
# iteration 1100 / 1500: loss 2.089494
# iteration 1200 / 1500: loss 2.074332
# iteration 1300 / 1500: loss 2.074691
# iteration 1400 / 1500: loss 2.064070
# iteration 0 / 1500: loss 1541.993535
# iteration 100 / 1500: loss 139.259914
# iteration 200 / 1500: loss 14.336848
# iteration 300 / 1500: loss 3.232654
# iteration 400 / 1500: loss 2.258844
# iteration 500 / 1500: loss 2.107965
# iteration 600 / 1500: loss 2.147723
# iteration 700 / 1500: loss 2.072657
# iteration 800 / 1500: loss 2.174096
# iteration 900 / 1500: loss 2.169460
# iteration 1000 / 1500: loss 2.120635
# iteration 1100 / 1500: loss 2.082734
# iteration 1200 / 1500: loss 2.151530
# iteration 1300 / 1500: loss 2.128975
# iteration 1400 / 1500: loss 2.165589
# iteration 0 / 1500: loss 310.604929
# iteration 100 / 1500: loss 181.422983
# iteration 200 / 1500: loss 106.757244
# iteration 300 / 1500: loss 63.079376
# iteration 400 / 1500: loss 37.816055
# iteration 500 / 1500: loss 22.846148
# iteration 600 / 1500: loss 14.328654
# iteration 700 / 1500: loss 9.125902
# iteration 800 / 1500: loss 6.210727
# iteration 900 / 1500: loss 4.476588
# iteration 1000 / 1500: loss 3.400289
# iteration 1100 / 1500: loss 2.808420
# iteration 1200 / 1500: loss 2.465372
# iteration 1300 / 1500: loss 2.364860
# iteration 1400 / 1500: loss 2.145340
# iteration 0 / 1500: loss 922.463394
# iteration 100 / 1500: loss 185.683734
# iteration 200 / 1500: loss 38.862814
# iteration 300 / 1500: loss 9.445246
# iteration 400 / 1500: loss 3.578688
# iteration 500 / 1500: loss 2.304395
# iteration 600 / 1500: loss 2.134142
# iteration 700 / 1500: loss 2.117295
# iteration 800 / 1500: loss 2.118852
# iteration 900 / 1500: loss 2.107571
# iteration 1000 / 1500: loss 2.108083
# iteration 1100 / 1500: loss 2.099707
# iteration 1200 / 1500: loss 2.119551
# iteration 1300 / 1500: loss 2.037194
# iteration 1400 / 1500: loss 2.067174
# iteration 0 / 1500: loss 1540.935690
# iteration 100 / 1500: loss 106.595022
# iteration 200 / 1500: loss 9.240530
# iteration 300 / 1500: loss 2.635304
# iteration 400 / 1500: loss 2.127572
# iteration 500 / 1500: loss 2.120837
# iteration 600 / 1500: loss 2.182760
# iteration 700 / 1500: loss 2.184524
# iteration 800 / 1500: loss 2.137389
# iteration 900 / 1500: loss 2.139310
# iteration 1000 / 1500: loss 2.152934
# iteration 1100 / 1500: loss 2.149676
# iteration 1200 / 1500: loss 2.165373
# iteration 1300 / 1500: loss 2.124982
# iteration 1400 / 1500: loss 2.081777
# iteration 0 / 1500: loss 315.123960
# iteration 100 / 1500: loss 174.695029
# iteration 200 / 1500: loss 97.473334
# iteration 300 / 1500: loss 54.889482
# iteration 400 / 1500: loss 31.392442
# iteration 500 / 1500: loss 18.260533
# iteration 600 / 1500: loss 10.997835
# iteration 700 / 1500: loss 7.036047
# iteration 800 / 1500: loss 4.754127
# iteration 900 / 1500: loss 3.626011
# iteration 1000 / 1500: loss 2.827412
# iteration 1100 / 1500: loss 2.463293
# iteration 1200 / 1500: loss 2.244194
# iteration 1300 / 1500: loss 2.134775
# iteration 1400 / 1500: loss 2.032935
# iteration 0 / 1500: loss 916.000609
# iteration 100 / 1500: loss 157.243259
# iteration 200 / 1500: loss 28.388875
# iteration 300 / 1500: loss 6.581543
# iteration 400 / 1500: loss 2.858438
# iteration 500 / 1500: loss 2.260983
# iteration 600 / 1500: loss 2.156522
# iteration 700 / 1500: loss 2.041364
# iteration 800 / 1500: loss 2.116799
# iteration 900 / 1500: loss 2.109694
# iteration 1000 / 1500: loss 2.089272
# iteration 1100 / 1500: loss 2.135500
# iteration 1200 / 1500: loss 2.093520
# iteration 1300 / 1500: loss 2.102514
# iteration 1400 / 1500: loss 2.030809
# iteration 0 / 1500: loss 1549.544313
# iteration 100 / 1500: loss 82.255890
# iteration 200 / 1500: loss 6.264471
# iteration 300 / 1500: loss 2.375126
# iteration 400 / 1500: loss 2.075523
# iteration 500 / 1500: loss 2.095585
# iteration 600 / 1500: loss 2.131714
# iteration 700 / 1500: loss 2.091467
# iteration 800 / 1500: loss 2.163182
# iteration 900 / 1500: loss 2.097679
# iteration 1000 / 1500: loss 2.176837
# iteration 1100 / 1500: loss 2.155797
# iteration 1200 / 1500: loss 2.176184
# iteration 1300 / 1500: loss 2.177547
# iteration 1400 / 1500: loss 2.160146
# iteration 0 / 1500: loss 314.206212
# iteration 100 / 1500: loss 165.134145
# iteration 200 / 1500: loss 87.494293
# iteration 300 / 1500: loss 46.869422
# iteration 400 / 1500: loss 25.595540
# iteration 500 / 1500: loss 14.400914
# iteration 600 / 1500: loss 8.468887
# iteration 700 / 1500: loss 5.440016
# iteration 800 / 1500: loss 3.840071
# iteration 900 / 1500: loss 2.932498
# iteration 1000 / 1500: loss 2.470938
# iteration 1100 / 1500: loss 2.251807
# iteration 1200 / 1500: loss 2.137809
# iteration 1300 / 1500: loss 2.112261
# iteration 1400 / 1500: loss 2.012426
# iteration 0 / 1500: loss 924.748987
# iteration 100 / 1500: loss 135.337881
# iteration 200 / 1500: loss 21.343051
# iteration 300 / 1500: loss 4.886975
# iteration 400 / 1500: loss 2.525873
# iteration 500 / 1500: loss 2.185811
# iteration 600 / 1500: loss 2.100544
# iteration 700 / 1500: loss 2.096842
# iteration 800 / 1500: loss 2.099657
# iteration 900 / 1500: loss 2.131708
# iteration 1000 / 1500: loss 2.053307
# iteration 1100 / 1500: loss 2.097689
# iteration 1200 / 1500: loss 2.071473
# iteration 1300 / 1500: loss 2.108229
# iteration 1400 / 1500: loss 2.131179
# iteration 0 / 1500: loss 1534.251426
# iteration 100 / 1500: loss 62.623880
# iteration 200 / 1500: loss 4.538014
# iteration 300 / 1500: loss 2.240452
# iteration 400 / 1500: loss 2.177715
# iteration 500 / 1500: loss 2.158280
# iteration 600 / 1500: loss 2.198116
# iteration 700 / 1500: loss 2.173936
# iteration 800 / 1500: loss 2.159473
# iteration 900 / 1500: loss 2.165116
# iteration 1000 / 1500: loss 2.136442
# iteration 1100 / 1500: loss 2.183531
# iteration 1200 / 1500: loss 2.164129
# iteration 1300 / 1500: loss 2.113189
# iteration 1400 / 1500: loss 2.129227
# iteration 0 / 1500: loss 317.165146
# iteration 100 / 1500: loss 158.254970
# iteration 200 / 1500: loss 79.541913
# iteration 300 / 1500: loss 40.540486
# iteration 400 / 1500: loss 21.315517
# iteration 500 / 1500: loss 11.592421
# iteration 600 / 1500: loss 6.777641
# iteration 700 / 1500: loss 4.382143
# iteration 800 / 1500: loss 3.194647
# iteration 900 / 1500: loss 2.571585
# iteration 1000 / 1500: loss 2.280124
# iteration 1100 / 1500: loss 2.142294
# iteration 1200 / 1500: loss 2.020087
# iteration 1300 / 1500: loss 2.043854
# iteration 1400 / 1500: loss 2.014351
# iteration 0 / 1500: loss 930.435277
# iteration 100 / 1500: loss 116.088340
# iteration 200 / 1500: loss 16.203170
# iteration 300 / 1500: loss 3.806013
# iteration 400 / 1500: loss 2.339013
# iteration 500 / 1500: loss 2.138658
# iteration 600 / 1500: loss 2.054785
# iteration 700 / 1500: loss 1.999515
# iteration 800 / 1500: loss 2.136463
# iteration 900 / 1500: loss 2.123994
# iteration 1000 / 1500: loss 2.106332
# iteration 1100 / 1500: loss 2.057160
# iteration 1200 / 1500: loss 2.125186
# iteration 1300 / 1500: loss 2.110090
# iteration 1400 / 1500: loss 2.111083
# iteration 0 / 1500: loss 1541.048307
# iteration 100 / 1500: loss 48.450848
# iteration 200 / 1500: loss 3.518315
# iteration 300 / 1500: loss 2.194309
# iteration 400 / 1500: loss 2.131435
# iteration 500 / 1500: loss 2.190628
# iteration 600 / 1500: loss 2.074024
# iteration 700 / 1500: loss 2.161487
# iteration 800 / 1500: loss 2.167155
# iteration 900 / 1500: loss 2.154900
# iteration 1000 / 1500: loss 2.135844
# iteration 1100 / 1500: loss 2.164268
# iteration 1200 / 1500: loss 2.193256
# iteration 1300 / 1500: loss 2.166910
# iteration 1400 / 1500: loss 2.122904
# iteration 0 / 1500: loss 311.763777
# iteration 100 / 1500: loss 147.445604
# iteration 200 / 1500: loss 70.564022
# iteration 300 / 1500: loss 34.197546
# iteration 400 / 1500: loss 17.327608
# iteration 500 / 1500: loss 9.189986
# iteration 600 / 1500: loss 5.403852
# iteration 700 / 1500: loss 3.587124
# iteration 800 / 1500: loss 2.743299
# iteration 900 / 1500: loss 2.271043
# iteration 1000 / 1500: loss 2.142631
# iteration 1100 / 1500: loss 2.095474
# iteration 1200 / 1500: loss 1.941218
# iteration 1300 / 1500: loss 2.031264
# iteration 1400 / 1500: loss 2.016865
# iteration 0 / 1500: loss 924.801486
# iteration 100 / 1500: loss 98.366758
# iteration 200 / 1500: loss 12.183586
# iteration 300 / 1500: loss 3.142507
# iteration 400 / 1500: loss 2.190644
# iteration 500 / 1500: loss 2.115459
# iteration 600 / 1500: loss 2.106661
# iteration 700 / 1500: loss 2.076808
# iteration 800 / 1500: loss 2.104784
# iteration 900 / 1500: loss 2.108668
# iteration 1000 / 1500: loss 2.122773
# iteration 1100 / 1500: loss 2.109224
# iteration 1200 / 1500: loss 2.135413
# iteration 1300 / 1500: loss 2.131743
# iteration 1400 / 1500: loss 2.087213
# iteration 0 / 1500: loss 1543.589724
# iteration 100 / 1500: loss 37.507159
# iteration 200 / 1500: loss 2.952010
# iteration 300 / 1500: loss 2.160092
# iteration 400 / 1500: loss 2.168209
# iteration 500 / 1500: loss 2.185058
# iteration 600 / 1500: loss 2.178453
# iteration 700 / 1500: loss 2.146778
# iteration 800 / 1500: loss 2.116545
# iteration 900 / 1500: loss 2.139824
# iteration 1000 / 1500: loss 2.159814
# iteration 1100 / 1500: loss 2.173429
# iteration 1200 / 1500: loss 2.122218
# iteration 1300 / 1500: loss 2.193761
# iteration 1400 / 1500: loss 2.173293
# iteration 0 / 1500: loss 313.402361
# iteration 100 / 1500: loss 140.536142
# iteration 200 / 1500: loss 63.682898
# iteration 300 / 1500: loss 29.611825
# iteration 400 / 1500: loss 14.301333
# iteration 500 / 1500: loss 7.466559
# iteration 600 / 1500: loss 4.538265
# iteration 700 / 1500: loss 3.167983
# iteration 800 / 1500: loss 2.499225
# iteration 900 / 1500: loss 2.265847
# iteration 1000 / 1500: loss 2.131373
# iteration 1100 / 1500: loss 2.055394
# iteration 1200 / 1500: loss 2.046569
# iteration 1300 / 1500: loss 2.054130
# iteration 1400 / 1500: loss 2.055762
# iteration 0 / 1500: loss 939.518723
# iteration 100 / 1500: loss 85.313557
# iteration 200 / 1500: loss 9.561172
# iteration 300 / 1500: loss 2.783075
# iteration 400 / 1500: loss 2.159631
# iteration 500 / 1500: loss 2.061089
# iteration 600 / 1500: loss 2.046139
# iteration 700 / 1500: loss 2.095141
# iteration 800 / 1500: loss 2.064109
# iteration 900 / 1500: loss 2.049550
# iteration 1000 / 1500: loss 2.140778
# iteration 1100 / 1500: loss 2.149230
# iteration 1200 / 1500: loss 2.050340
# iteration 1300 / 1500: loss 2.153931
# iteration 1400 / 1500: loss 2.071488
# iteration 0 / 1500: loss 1525.719751
# iteration 100 / 1500: loss 28.750226
# iteration 200 / 1500: loss 2.612200
# iteration 300 / 1500: loss 2.146391
# iteration 400 / 1500: loss 2.107185
# iteration 500 / 1500: loss 2.134537
# iteration 600 / 1500: loss 2.151038
# iteration 700 / 1500: loss 2.137029
# iteration 800 / 1500: loss 2.169043
# iteration 900 / 1500: loss 2.162368
# iteration 1000 / 1500: loss 2.179183
# iteration 1100 / 1500: loss 2.191193
# iteration 1200 / 1500: loss 2.171608
# iteration 1300 / 1500: loss 2.149073
# iteration 1400 / 1500: loss 2.140208
# lr 8.000000e-08 reg 1.000000e+04 train accuracy: 0.345347 val accuracy: 0.362000
# lr 8.000000e-08 reg 3.000000e+04 train accuracy: 0.319714 val accuracy: 0.335000
# lr 8.000000e-08 reg 5.000000e+04 train accuracy: 0.301776 val accuracy: 0.317000
# lr 9.333333e-08 reg 1.000000e+04 train accuracy: 0.351673 val accuracy: 0.356000
# lr 9.333333e-08 reg 3.000000e+04 train accuracy: 0.319367 val accuracy: 0.334000
# lr 9.333333e-08 reg 5.000000e+04 train accuracy: 0.306265 val accuracy: 0.323000
# lr 1.066667e-07 reg 1.000000e+04 train accuracy: 0.355245 val accuracy: 0.373000
# lr 1.066667e-07 reg 3.000000e+04 train accuracy: 0.327959 val accuracy: 0.337000
# lr 1.066667e-07 reg 5.000000e+04 train accuracy: 0.314306 val accuracy: 0.327000
# lr 1.200000e-07 reg 1.000000e+04 train accuracy: 0.358755 val accuracy: 0.370000
# lr 1.200000e-07 reg 3.000000e+04 train accuracy: 0.319959 val accuracy: 0.326000
# lr 1.200000e-07 reg 5.000000e+04 train accuracy: 0.310714 val accuracy: 0.327000
# lr 1.333333e-07 reg 1.000000e+04 train accuracy: 0.357367 val accuracy: 0.378000
# lr 1.333333e-07 reg 3.000000e+04 train accuracy: 0.318143 val accuracy: 0.341000
# lr 1.333333e-07 reg 5.000000e+04 train accuracy: 0.317612 val accuracy: 0.332000
# lr 1.466667e-07 reg 1.000000e+04 train accuracy: 0.354612 val accuracy: 0.365000
# lr 1.466667e-07 reg 3.000000e+04 train accuracy: 0.329184 val accuracy: 0.336000
# lr 1.466667e-07 reg 5.000000e+04 train accuracy: 0.304510 val accuracy: 0.319000
# lr 1.600000e-07 reg 1.000000e+04 train accuracy: 0.354000 val accuracy: 0.377000
# lr 1.600000e-07 reg 3.000000e+04 train accuracy: 0.323571 val accuracy: 0.326000
# lr 1.600000e-07 reg 5.000000e+04 train accuracy: 0.309061 val accuracy: 0.329000
# lr 1.733333e-07 reg 1.000000e+04 train accuracy: 0.355796 val accuracy: 0.369000
# lr 1.733333e-07 reg 3.000000e+04 train accuracy: 0.315592 val accuracy: 0.330000
# lr 1.733333e-07 reg 5.000000e+04 train accuracy: 0.309367 val accuracy: 0.322000
# lr 1.866667e-07 reg 1.000000e+04 train accuracy: 0.355449 val accuracy: 0.360000
# lr 1.866667e-07 reg 3.000000e+04 train accuracy: 0.324000 val accuracy: 0.341000
# lr 1.866667e-07 reg 5.000000e+04 train accuracy: 0.308571 val accuracy: 0.320000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.357673 val accuracy: 0.371000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.321959 val accuracy: 0.340000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.307163 val accuracy: 0.321000
# best validation accuracy achieved during cross-validation: 0.378000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.371000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$True
#
#
# $\color{blue}{\textit Your Explanation:}$ In svm loss depends on the relative score and if the score of the added datapoint is 1(margin) less than the correct score then the total loss remains unchanged whereas in softmax every datapoint has some contribution in the total loss.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
